# %% [markdown]
# # Reacher (20 agents) report
# ## Learning algorithm
# Deep Deterministic Policy Gradient (DDPG) for continuous action spaces, with following parameters:
# ![image.png](attachment:image.png)
#
# Using Actor network and Critic network, with following layers:
# ![image-3.png](attachment:image-3.png)
#
# ## Training result
# After few updates of network layers size, environment solved after 131 episodes
# ![image-4.png](attachment:image-4.png)
#
# ## What can we do next?
# Here are some ideas:
# - Add noise
# - N-step bootstrapings
# - Tunning hyperparameters of Agent
# - Adjust network architecture
